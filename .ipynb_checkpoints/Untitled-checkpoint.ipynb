# %%
import pandas as pd

# %%
df = pd.read_csv('~/code/steph-grigors/Speaker_recognition_project/train.csv')

# %%
df.head(50)
# Out:
#            id                   file_path  \
# 0   rxr_a0591  train/rxr/arctic_a0591.wav
# 1   rxr_a0403  train/rxr/arctic_a0403.wav
# 2   ljm_a0059  train/ljm/arctic_a0059.wav
# 3   jmk_a0134  train/jmk/arctic_a0134.wav
# 4   rms_b0067  train/rms/arctic_b0067.wav
# 5   gka_a0290  train/gka/arctic_a0290.wav
# 6   ksp_a0501  train/ksp/arctic_a0501.wav
# 7   ksp_a0058  train/ksp/arctic_a0058.wav
# 8   awb_b0220  train/awb/arctic_b0220.wav
# 9   jmk_a0086  train/jmk/arctic_a0086.wav
# 10  clb_a0418  train/clb/arctic_a0418.wav
# 11  rxr_a0039  train/rxr/arctic_a0039.wav
# 12  fem_a0290  train/fem/arctic_a0290.wav
# 13  clb_b0470  train/clb/arctic_b0470.wav
# 14  ljm_a0390  train/ljm/arctic_a0390.wav
# 15  bdl_a0437  train/bdl/arctic_a0437.wav
# 16  lnh_a0098  train/lnh/arctic_a0098.wav
# 17  ahw_a0539  train/ahw/arctic_a0539.wav
# 18  ksp_a0561  train/ksp/arctic_a0561.wav
# 19  rxr_c0030  train/rxr/arctic_c0030.wav
# 20  jmk_a0558  train/jmk/arctic_a0558.wav
# ...

# %%
df['speaker'].value_counts()
# Out:
# awb    910
# rms    906
# aew    906
# ksp    906
# clb    906
# slt    906
# bdl    905
# lnh    905
# jmk    891
# rxr    533
# ljm    474
# ahw    474
# slp    474
# fem    474
# eey    474
# gka    474
# axb    474
# aup    474
# Name: speaker, dtype: int64
